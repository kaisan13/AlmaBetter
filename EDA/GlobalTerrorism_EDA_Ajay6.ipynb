# %% [markdown]
# <a href="https://colab.research.google.com/github/kaisan13/AlmaBetter/blob/main/EDA/GlobalTerrorism_EDA_Ajay6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name** - Global Terrorism Dataset  .

# %% [markdown]
# ##### Project Type   - EDA
# ##### **Contribution**   Team
# ##### Team member 1- Ajay kumar Singh
# ##### Team member 2- Purnima Pandey

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In our team, their are two members and their names are Ajay Kumar Singh, Purnima Pandey. we are working together on **Exploratory Data** **Analysis** on the topic of **Global Terrorism Dataset**(**GTD**). We have decided to choose this project to find out hot zones of terrorism, security issues and key insights by ensuring through visualization.
#
# **"The threatened or actual use of illegal force and violence by a non-state actor to attain a political, economic, religious or social goal through fear, coercion or intimidation"**.Generally, terrorism is defined as an unlawful use of violence designed to further political aims by creating fear. This means that it can be difficult to define which violent acts should be classified as terrorism, and cases where the perpetrator does not have a political motivation. For example, it is not clear on the status of violence in wars of national liberation and self-determination. This lack of universal agreement has hampered the ability of the international community to co-ordinate efforts to combat terrorism.Terrorism is by no means just a 21st century issue, with attacks that could be described as terrorism dating back as far as the Roman Empire.Turning to more modern times, looking at the number of terror attack victims in Western Europe since 1970 shows more victims in the 1970s and 1980s than in the 2000s. Much of this violence was enacted by** Nationalist Movements such as the IRA or the ETA **, as well as political extremists on both the left and right. Moreover, the 1970s and 1980s saw a range of high-profiled plane hijackings, for instance the hijacking of the Landshut between Spain and Germany in 1977, and the hijacking of the Air France flight that was redirected to Entebbe in Uganda in 1976. However, there has been a number of deadly terrorist attacks in Europe since the turn of the millennium, with seven of the 10 deadliest terrorist attacks on the continent happening since 2004.
#
#   **The Global Terrorism Dataset**(**GTD**) is a database on terrorist attacks around the world from **1970 to 2017** containing **over 180,000 attacks.** **Researchers at The National Consortium** maintain the database for **The** **Study Of Terrorism And Responses To Terrorism**(**START**), headquartered at the **"University Of Maryland"**. In this database there are **135 columns and 181,691 rows** of different variables. The primary purpose of the project is to dive into generating visualizations, surrounding time and what they demonstrate. It had to focus on global bombings between **1970 to** **2017**, as of now attacks have become more deadly with the lethality rising by 26% and **Islamic States**(**IS**) and it affiliates remained the world's deadliest terrorist group for the eight consecutive years, with attacks in 21 countries and Islamic State, the deadliest, saw an increase of 12% to 2.9 deaths per attack, while al-Shabaab's lethality rate is at its highest level since 2017, if we look at Global Terrorism Index 2023, Afghanistan is the country which is mostly affected by terrorism in 2023 and India's rank is 13th globally. The hub of terrorism is rapidly changing and moving towards countries facing political instability, conflict and ecological degradation, particularly in the Sahel. Deaths from terrorism in the Sahel increased by 7% and are now higher than South Asia and** Middle East and North Africa**(**MENA**) combined. The area is also the most impacted region in the world, representing 43% of deaths from terrorism globally, this index is produced by **The Institute For Economics And Piece**(**IEP**), think tank, using data from terrorism tracker and other sources. Now, the next two deadliest terrorist groups are **Balochistan Liberation Army**(**BLA**) and **Jama’at Nasr al-Islam Wal Muslimeen**(**JNIM**).

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The problem of analyzing a global terrorism dataset aims to gain insights into patterns, trends, and characteristics of terrorist incidents and organizations worldwide. The dataset could contain information about various attributes such as the location, date, type of attack, target, casualties, responsible groups, and more. The goal of analyzing this dataset could be to extract meaningful information to aid policymakers, law enforcement agencies, and researchers in understanding and countering terrorism effectively.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Business Objective:
#
#
# The business goal is to conduct exploratory data analysis on a dataset, creating visualizations of attack types, high-sensitivity areas, and attack frequencies. The aim is to extract meaningful insights and conclusions about global terrorism trends.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
file_path='/content/drive/MyDrive/Colab Notebooks/Global Terrorism Dataset EDA/Global Terrorism Data.csv'

gtd_df = pd.read_csv(file_path,encoding="Latin-1")
gtd_df
# Out:
# Mounted at /content/drive
# <ipython-input-2-03b71c6fedc7>:6: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   gtd_df = pd.read_csv(file_path,encoding="Latin-1")
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# ...

# %%
# gtd_df.rename(columns ={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'State','region_txt':'Region',
                        # 'city':'City','latitude':'Latitude','longitude':'Longitude','attacktype1_txt':'AttackType','nkill':'Killed',
                        # 'nwound':'Wounded','target1':'Target','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                        # 'weaptype1_txt':'Weapon_type','weapdetail':'Weapon_Detail','success':'Success','targsubtype1_txt':'Sub_Target',
                        # 'natlty1_txt':'Nationality','multiple':'Multiple','suicide':'Suicide','motive':'Motive'},inplace=True)


# gtd_df = df[['Year','Month','Day','Country','State','Region','City','Latitude','Longitude','AttackType','Killed',
              #  'Wounded','Target','Summary','Group','Target_type','Weapon_type','Weapon_Detail','Success','Multiple',
              #  'Nationality','Sub_Target','Suicide','Motive']]

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
gtd_df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
gtd_df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %%
gtd_df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region                  region_txt  \
# 181686      182      Somalia      11          Sub-Saharan Africa
# 181687      200        Syria      10  Middle East & North Africa
# 181688      160  Philippines       5              Southeast Asia
# 181689       92        India       6                  South Asia
# 181690      160  Philippines       5              Southeast Asia
#
#               provstate           city   latitude   longitude  specificity  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(gtd_df.shape)
print(gtd_df.shape[0])
print(gtd_df.shape[1])
print('number of rows: ' ,gtd_df.shape[0])
print('number of columns: ',gtd_df.shape[1])
# Out:
# (181691, 135)
# 181691
# 135
# number of rows:  181691
# number of columns:  135

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
column_info = pd.DataFrame(gtd_df.dtypes).reset_index()
column_info.columns = ['Column Name', 'Data Type']
column_info['Non-Null Count'] = gtd_df.count().values
print(column_info)
# Out:
#             Column Name Data Type  Non-Null Count
# 0               eventid     int64          181691
# 1                 iyear     int64          181691
# 2                imonth     int64          181691
# 3                  iday     int64          181691
# 4            approxdate    object            9239
# 5              extended     int64          181691
# 6            resolution    object            2220
# 7               country     int64          181691
# 8           country_txt    object          181691
# 9                region     int64          181691
# 10           region_txt    object          181691
# 11            provstate    object          181270
# 12                 city    object          181257
# 13             latitude   float64          177135
# 14            longitude   float64          177134
# 15          specificity   float64          181685
# 16             vicinity     int64          181691
# 17             location    object           55495
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
# duplicate_value = gtd_df.duplicated().sum()
# print('number_of_duplicate_values: ',duplicate_value)
duplicate_value = gtd_df.duplicated().sum()
# print(duplicate_value)
print("number of duplicate value:", duplicate_value)
# Out:
# number of duplicate value: 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(gtd_df.isnull().sum())
misscount = gtd_df.isnull().sum().sum()
print(misscount)
# Out:
# eventid                    0
# iyear                      0
# imonth                     0
# iday                       0
# approxdate            172452
# extended                   0
# resolution            179471
# country                    0
# country_txt                0
# region                     0
# region_txt                 0
# provstate                421
# city                     434
# latitude                4556
# longitude               4557
# specificity                6
# vicinity                   0
# location              126196
# summary                66129
# crit1                      0
# crit2                      0
# crit3                      0
# doubtterr                  1
# alternative           152680
# alternative_txt       152680
# multiple                   1
# success                    0
# suicide                    0
# attacktype1                0
# attacktype1_txt            0
# attacktype2           175377
# attacktype2_txt       175377
# ...

# %%
# Visualizing the missing values
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the percentage of missing values in each column
missing_percentage = (gtd_df.isnull().sum() / len(gtd_df)) * 100

# Filter columns with missing values
columns_with_missing = missing_percentage[missing_percentage > 0]

# Create a bar plot of missing value percentages for columns with missing values
plt.figure(figsize=(10, 30))
ax = sns.barplot(y=columns_with_missing.index, x=columns_with_missing.values)
plt.title('Percentage of Missing Values by Column')
plt.ylabel('Percentage')
plt.xticks(rotation=45, ha='right')
plt.gca().yaxis.grid(True)  # Add horizontal grid lines
# Display percentage values on top of bars
# for p in ax.patches:
    # ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=10, color='blue', xytext=(0, 5), textcoords='offset points')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# 1-The Global Terrorism Dataset(GTD) defines a terrorist attack as the threatened or actual use of illegal
# force and violence by a non-state actor to attain a political, economic, religious, or social goal through fear, coercion, or
# intimidation.
#
# 2-A term also find in the dataset where the country in which an incident occurred cannot be identified, it is coded as “Unknown.”
#
# 3-The dataset consists of four major data types: bool(2), float64(2), int64(5) and object(14).
#
# 4-The numerical data in the dataset is represented by float64 (2) and int64 (5) data types. These numerical variables likely contain information such as year, month, day, latitude, longitude, and other variables also.
#
# 5-furthermore, there are object (14) data types in the dataset that store categorical information such as country, state, region, city . These variables provide context and additional details about where the attack happened.
#
#
# 6-While analyzing the dataset we come to the point, that in each year which city or region attack occured and which segment targeted also which gang or organization behind the attack and they used different types of weapons in the attack. This information can be valuable for understanding the tendency of occurring attacks and target to people, selection of region, usage patterns in focused to especially high density countries and potentially identifying areas for improvement or optimization in global terrorism.
#
#
# 7-In safety terms, this initial dataset overview provides a concise summary of the dataset's structure, including the data types, dimensions, presence of null values, and the types of information contained in the numerical and categorical variables.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset column
print("Column list:")
print(gtd_df.columns)
# Out:
# Column list:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
# Dataset Describe
gtd_df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1) **Success**:- This variable indicates whether a terrorist attack was successful or not. The description could mention the success rate based on the mean value and highlight the proportion of successful attacks.
#
# 2) **Attack_year**:- The year of the terrorist attack. The description could mention the range of years present in the dataset and any trends observed over the years.
#
# 3) **Attack_week_number**:- The week number of the year for the attack date. The description could mention any patterns in attack frequency based on the week number.
#
# 4) **Attack_day_of_month**:- The day of the month for the attack date. The description could discuss any patterns related to specific days of the month.
#
# 5) **Attacks_in_week**:- The number of attacks that occurred during weekdays. The description could discuss the average number of weekday attacks and the overall frequency of attacks.
#
# 6) **Country**:- This identifies the country or location where the attack occurred. In the case where the country in which an incident occurred cannot be identified, it is coded as “Unknown”.
#
# 7) **State**:- This variable records the name at the time of event of the administrative region in which the event occurs.
#
# 8) **Region**:- This field identifies the region in which the incident occurred. The regions are divided into 12 categories,eg-North America, Central America & Caribbean, South America, East Asia, Southeast Asia, South Asia, Central Asia, Western Europe, Eastern Europe, Middle East & North Africa, Sub-Saharan Africa, Australasia & Oceania.
#
# 9) **City**:- This field contains the name of the city, village, or town in which the incident occurred.
#
# 10) **Latitude**:- This field records the latitude of the city in which the event occurred.
#
# 11) **Longitude**:- This field records the longitude of the city in which the event occurred.
#
# 12) **Attack type**:- This field captures the general method of attack and often reflects the broad class of tactics used. It consists of nine categories,Assassination, Hijacking, Kidnapping, Barricade Incident, Bombing/Explosion, Armed Assault, Unarmed Assault, Facility/Infrastructure Attack, Unknown that is not recorded.
#
# 13) **Killed**:- The field contains information about how many people killed in the incident.
#
# 14) **Wounded**:- This field records the wounded people during the attack happened .
#
# 15) **Target**:- The field contains information on both intended targets and incidental bystanders.
#
# 16) **Group**:-This field contains the name of the group that carried out the attack.
#
# 17) **Weapon type**:- In this categoy general type of the weapons used in an attack are recorded. I
#
# 18) **Weapon Detail**:-This field notes any pertinent information on the type of weapons used in the incident. Such notes could include the novel use or means of concealing a weapon, specific weapon models, interesting details of the weapons’ origins, etc.
#
# 19) **Target type**:- The target/victim type field captures the general type of target/victim. When a victim is attacked specifically because of his or her relationship to a particular person, such as a prominent figure, the target type reflects that motive.It includes government, police,military, airports and aircrafts, educational institutions,food or water supply, jounalists and media, maritime, non-governmental organization, private citizens and property, religious figures / institutions, telecommunication, tourists, violent political parties.
#
# 20) **Sub Target**:-  The variable captures the more specific target category and provides the next level of designation for each target type. If a target subtype is not applicable this variable is left blank.
#
# 21) **Summary**:- This field contains all the information about the attack occurred , motive, casulties, weapon used in the attack and place where the attack occurred.
#
# 22) **Nationality**:- It defines the nationality that the citizens have where the attack occurred.
#
# 23) **Motive**:- It elaborates the motive why the paticular place targeted to attack or protest.
#
# 24) **Multiple**:-
# It has come to our attention that multiple attacks have been perpetrated.
#
# 25) **Suicide**:- When the people are committing the suicide then it comes under this content.

# %% [markdown]
# ####**Selecting important data features**

# %%
gtd_df.rename(columns ={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'State','region_txt':'Region',
                        'city':'City','latitude':'Latitude','longitude':'Longitude','attacktype1_txt':'AttackType','nkill':'Killed',
                        'nwound':'Wounded','target1':'Target','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                        'weaptype1_txt':'Weapon_type','weapdetail':'Weapon_Detail','success':'Success','targsubtype1_txt':'Sub_Target',
                        'natlty1_txt':'Nationality','multiple':'Multiple','suicide':'Suicide','motive':'Motive'},inplace=True)


gtd_df = gtd_df[['Year','Month','Day','Country','State','Region','City','Latitude','Longitude','AttackType','Killed',
               'Wounded','Target','Summary','Group','Target_type','Weapon_type','Weapon_Detail','Success','Multiple',
               'Nationality','Sub_Target','Suicide','Motive']]

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
print(gtd_df.nunique())
# Out:
# Year                 47
# Month                13
# Day                  32
# Country             205
# State              2855
# Region               12
# City              36674
# Latitude          48322
# Longitude         48039
# AttackType            9
# Killed              205
# Wounded             238
# Target            86006
# Summary          112492
# Group              3537
# Target_type          22
# Weapon_type          12
# Weapon_Detail     19148
# Success               2
# Multiple              2
# Nationality         215
# Sub_Target          112
# Suicide               2
# Motive            14490
# dtype: int64

# %%
gtd_df['Day'].unique()
# Out:
# array([ 2,  0,  1,  3,  6,  8,  9, 10, 11, 12, 13, 14, 15, 19, 20, 21, 22,
#        25, 26, 27, 28, 30, 31,  4,  7, 16, 17, 18, 23, 24,  5, 29])

# %%
gtd_df['Month'].unique()
# Out:
# array([ 7,  0,  1,  2,  3,  4,  5,  6,  8,  9, 10, 11, 12])

# %%
gtd_df['Country'].unique()
# Out:
# array(['Dominican Republic', 'Mexico', 'Philippines', 'Greece', 'Japan',
#        'United States', 'Uruguay', 'Italy', 'East Germany (GDR)',
#        'Ethiopia', 'Guatemala', 'Venezuela', 'West Germany (FRG)',
#        'Switzerland', 'Jordan', 'Spain', 'Brazil', 'Egypt', 'Argentina',
#        'Lebanon', 'Ireland', 'Turkey', 'Paraguay', 'Iran',
#        'United Kingdom', 'Colombia', 'Bolivia', 'Nicaragua',
#        'Netherlands', 'Belgium', 'Canada', 'Australia', 'Pakistan',
#        'Zambia', 'Sweden', 'Costa Rica', 'South Yemen', 'Cambodia',
#        'Israel', 'Poland', 'Taiwan', 'Panama', 'Kuwait',
#        'West Bank and Gaza Strip', 'Austria', 'Czechoslovakia', 'India',
#        'France', 'South Vietnam', 'Brunei', 'Zaire',
#        "People's Republic of the Congo", 'Portugal', 'Algeria',
#        'El Salvador', 'Thailand', 'Haiti', 'Sudan', 'Morocco', 'Cyprus',
#        'Myanmar', 'Afghanistan', 'Peru', 'Chile', 'Honduras',
# ...

# %%
gtd_df['Region'].unique()
# Out:
# array(['Central America & Caribbean', 'North America', 'Southeast Asia',
#        'Western Europe', 'East Asia', 'South America', 'Eastern Europe',
#        'Sub-Saharan Africa', 'Middle East & North Africa',
#        'Australasia & Oceania', 'South Asia', 'Central Asia'],
#       dtype=object)

# %%
gtd_df['AttackType'].unique()
# Out:
# array(['Assassination', 'Hostage Taking (Kidnapping)',
#        'Bombing/Explosion', 'Facility/Infrastructure Attack',
#        'Armed Assault', 'Hijacking', 'Unknown', 'Unarmed Assault',
#        'Hostage Taking (Barricade Incident)'], dtype=object)

# %%
gtd_df['Target_type'].unique()
# Out:
# array(['Private Citizens & Property', 'Government (Diplomatic)',
#        'Journalists & Media', 'Police', 'Utilities', 'Military',
#        'Government (General)', 'Airports & Aircraft', 'Business',
#        'Educational Institution', 'Violent Political Party',
#        'Religious Figures/Institutions', 'Unknown', 'Transportation',
#        'Tourists', 'NGO', 'Telecommunication', 'Food or Water Supply',
#        'Terrorists/Non-State Militia', 'Other', 'Maritime',
#        'Abortion Related'], dtype=object)

# %%
gtd_df['Weapon_type'].unique()
# Out:
# array(['Unknown', 'Explosives', 'Incendiary', 'Firearms', 'Chemical',
#        'Melee', 'Sabotage Equipment',
#        'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)',
#        'Fake Weapons', 'Radiological', 'Other', 'Biological'],
#       dtype=object)

# %%
gtd_df['AttackType'].unique()
# Out:
# array(['Assassination', 'Hostage Taking (Kidnapping)',
#        'Bombing/Explosion', 'Facility/Infrastructure Attack',
#        'Armed Assault', 'Hijacking', 'Unknown', 'Unarmed Assault',
#        'Hostage Taking (Barricade Incident)'], dtype=object)

# %%
gtd_df['Success'].unique()
# Out:
# array([1, 0])

# %%
gtd_df['Multiple'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
gtd_df['Sub_Target'].unique()
# Out:
# array(['Named Civilian',
#        'Diplomatic Personnel (outside of embassy, consulate)',
#        'Radio Journalist/Staff/Facility', 'Embassy/Consulate',
#        'Police Building (headquarters, station, school)',
#        'Police Security Forces/Officers', 'Electricity',
#        'Military Recruiting Station/Academy',
#        'Government Building/Facility/Office',
#        'Military Barracks/Base/Headquarters/Checkpost',
#        'Aircraft (not at an airport)', 'Retail/Grocery/Bakery', nan,
#        'Military Personnel (soldiers, troops, officers, forces)',
#        'School/University/Educational Building',
#        'Multinational Corporation', 'Party Office/Facility',
#        'House/Apartment/Residence', 'Race/Ethnicity Identified',
#        'Judge/Attorney/Court',
#        'Police Patrol (including vehicles and convoys)',
#        'Place of Worship', 'Vehicles/Transportation',
#        'Bus (excluding tourists)',
#        'Politician or Political Party Movement/Meeting/Rally',
# ...

# %%
gtd_df.shape
print(gtd_df.shape)
gtd_df.isnull().sum()
# Out:
# (181691, 24)
# Year                  0
# Month                 0
# Day                   0
# Country               0
# State               421
# Region                0
# City                434
# Latitude           4556
# Longitude          4557
# AttackType            0
# Killed            10313
# Wounded           16311
# Target              636
# Summary           66129
# Group                 0
# Target_type           0
# Weapon_type           0
# Weapon_Detail     67670
# Success               0
# Multiple              1
# Nationality        1559
# Sub_Target        10373
# Suicide               0
# Motive           131130
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
gtd_df[gtd_df.duplicated()].shape
# Out:
# (9323, 24)

# %%
gtd_df.drop_duplicates(inplace=True)
gtd_df.shape
# Out:
# <ipython-input-29-9014d3d1762f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gtd_df.drop_duplicates(inplace=True)
# (172368, 24)

# %%
gtd_df.isnull().sum()
# Out:
# Year                  0
# Month                 0
# Day                   0
# Country               0
# State               421
# Region                0
# City                434
# Latitude           4013
# Longitude          4014
# AttackType            0
# Killed             9449
# Wounded           15285
# Target              552
# Summary           59221
# Group                 0
# Target_type           0
# Weapon_type           0
# Weapon_Detail     65364
# Success               0
# Multiple              1
# Nationality        1443
# Sub_Target         9465
# Suicide               0
# Motive           122451
# dtype: int64

# %%
# gtd_df = gtd_df.dropna()

# %%
gtd_df.isnull().sum()
# Out:
# Year                  0
# Month                 0
# Day                   0
# Country               0
# State               421
# Region                0
# City                434
# Latitude           4013
# Longitude          4014
# AttackType            0
# Killed             9449
# Wounded           15285
# Target              552
# Summary           59221
# Group                 0
# Target_type           0
# Weapon_type           0
# Weapon_Detail     65364
# Success               0
# Multiple              1
# Nationality        1443
# Sub_Target         9465
# Suicide               0
# Motive           122451
# dtype: int64

# %%
# df_name[Column_name].fillna(value, inplace = True) ; value = Value to replace with
gtd_df['State'].fillna('Unknown',inplace = True)
gtd_df['City'].fillna('Unknown',inplace = True)
gtd_df['Latitude'].fillna(0.0,inplace = True)
gtd_df['Longitude'].fillna(0.0,inplace = True)
gtd_df['Killed'].fillna(0,inplace = True)
gtd_df['Wounded'].fillna(0,inplace = True)
gtd_df['Target'].fillna('Unknown',inplace = True)
gtd_df['Summary'].fillna('Unknown',inplace = True)
gtd_df['Weapon_Detail'].fillna('Unknown',inplace = True)
gtd_df['Multiple'].fillna(0.0,inplace = True)
gtd_df['Sub_Target'].fillna('Unknown',inplace = True)
gtd_df['Nationality'].fillna('Unknown',inplace = True)
# Out:
# <ipython-input-33-3a54764578c8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gtd_df['State'].fillna('Unknown',inplace = True)
# <ipython-input-33-3a54764578c8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gtd_df['City'].fillna('Unknown',inplace = True)
# <ipython-input-33-3a54764578c8>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gtd_df['Latitude'].fillna(0.0,inplace = True)
# ...

# %%
# Write your code to make your dataset analysis ready.
gtd_df['Killed'] = gtd_df['Killed'].astype('int64')
gtd_df['Wounded'] = gtd_df['Wounded'].astype('int64')
gtd_df['Success'] = gtd_df['Success'].astype('bool')
gtd_df['Multiple'] = gtd_df['Multiple'].astype('bool')
# Out:
# <ipython-input-34-037553fedd0f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gtd_df['Killed'] = gtd_df['Killed'].astype('int64')
# <ipython-input-34-037553fedd0f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gtd_df['Wounded'] = gtd_df['Wounded'].astype('int64')
# <ipython-input-34-037553fedd0f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
gtd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 172368 entries, 0 to 181690
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Year           172368 non-null  int64
#  1   Month          172368 non-null  int64
#  2   Day            172368 non-null  int64
#  3   Country        172368 non-null  object
#  4   State          172368 non-null  object
#  5   Region         172368 non-null  object
#  6   City           172368 non-null  object
#  7   Latitude       172368 non-null  float64
#  8   Longitude      172368 non-null  float64
#  9   AttackType     172368 non-null  object
#  10  Killed         172368 non-null  int64
#  11  Wounded        172368 non-null  int64
#  12  Target         172368 non-null  object
#  13  Summary        172368 non-null  object
#  14  Group          172368 non-null  object
#  15  Target_type    172368 non-null  object
#  16  Weapon_type    172368 non-null  object
# ...

# %%
gtd_df['Multiple'].unique()
# Out:
# array([False,  True])

# %%
gtd_df['Success'].unique()
# Out:
# array([ True, False])

# %%
gtd_df['Killed'].unique()
# Out:
# array([   1,    0,    7,   47,    2,   36,    5,    3,    4,   25,   15,
#          26,    8,   81,    6,    9,   16,   30,   31,   12,   21,   14,
#          88,   11,   10,   27,   18,   22,   19,   92,   13,   73,  100,
#          42,   43,   17,   98,  422,   48,   34,   54,   50,   35,   20,
#          41,   37,   28,   40,   32,   85,   23,  300,   60,   24,   58,
#          70,   87,   45,   38,   29,   74,   83,   90,   66,   80,   67,
#          51,   39,  114,  124,   76,   33,   75,   57,   62,   46,   56,
#          63,  120,  102,   78,   79,   52,   77,  200,   49,  111,  165,
#          44,  241,   64,  108,   65,  132,  270,  228,  110,  136,  180,
#         250,   93,  130,   59,   94,   53,  146,  329,   97,   71,  240,
#         227,  126,  106,  388,   68,   84,   82,  171,  107,   55,  112,
#          72,   96,  140,   61,  105,  150,  115,   89, 1180,  170,  168,
#         121,  375,   91,  304,  123,  135,  256,  109,  271,  206,  104,
# ...

# %%
gtd_df['Wounded'].unique()
# Out:
# array([   0,    1,    2,    7,    9,   17,    5,    3,   10,   12,   20,
#           4,   11,   27,   13,   19,  130,   56,   24,    6,   72,  238,
#          55,   15,    8,   18,   50,   34,   14,   70,  102,   41,   48,
#          36,   25,   81,   54,   53,  100,   45,   33,   40,   62,   74,
#          22,   31,   16,   30,  285,   23,   42,   43,   76,   44,   52,
#          46,   49,  160,   37,   21,   60,   78,   26,   28,   39,   38,
#          35,   32,   80,   47,  188,  215,   85,   75,  161,   90,  300,
#          95,  135,   61,  138,   71,  700,   66,  136,  120,  217,  319,
#         133,   68,   73,   29,  751,  200,  112,  250,   82,  132,  230,
#         107,  114,   84,  140,  150,   96,   51,   58,   64,  295,  106,
#         125,   69,   59,   57,  122,  109,   88,  115,  176,  220,   97,
#          65,  800,  173,   92,  500,  236,   98,  286,  141, 5500,  650,
#         671,   86,  104,   83,  101, 1272,  105,  386,  391,  110,  149,
# ...

# %%
gtd_df_copy = gtd_df.copy()
gtd_df_copy.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic  Unknown  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   Latitude   Longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target  Summary  \
# ...

# %%
#1- How has the frequency of terrorist attacks changed over the past decade?

# Creating a copy of the DataFrame to avoid modification warnings
gtd_df_copy = gtd_df.copy()
# Create a new column 'Decade' by dividing the 'Year' by 10 and rounding down
gtd_df_copy['Decade'] = (gtd_df_copy['Year'] // 10)*10
# Grouping the data by 'Decade' and counting the number of incidents for each decade
atkBydecade = gtd_df_copy.groupby('Decade')['Decade'].count()
# Creating a custom DataFrame
atkBydecade_df = pd.DataFrame({'Decade': atkBydecade.index, 'IncidentCount':atkBydecade.values })
atkBydecade_df
# Out:
#    Decade  IncidentCount
# 0    1970           9369
# 1    1980          28070
# 2    1990          25418
# 3    2000          24917
# 4    2010          84594

# %%
#2- Which terrorist groups have been responsible for the largest number of casualties?
# Grouping the data by 'Group' and calculating the sum of killed and wounded for each group
group_casualties_df = gtd_df_copy.groupby('Group')['Killed', 'Wounded'].sum()

# Summing up killed and wounded to calculate total casualties for each group
group_casualties_df['TotalCasualties'] = group_casualties_df['Killed'] + group_casualties_df['Wounded']

# Sorting the DataFrame by total casualties
group_casualties_df = group_casualties_df.sort_values('TotalCasualties', ascending=False)

# Resetting the index and creating a custom DataFrame
group_casualties_df = group_casualties_df.reset_index()

# Display the custom DataFrame
group_casualties_df = group_casualties_df.head(11)
group_casualties_df.drop(0, inplace=True)
group_casualties_df
# Out:
# <ipython-input-42-6fddfebec24f>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   group_casualties_df = gtd_df_copy.groupby('Group')['Killed', 'Wounded'].sum()
#                                                Group  Killed  Wounded  \
# 1        Islamic State of Iraq and the Levant (ISIL)   38708    30511
# 2                                            Taliban   29186    27794
# 3                                         Boko Haram   20188     9369
# 4                                           Al-Qaida    3860    24512
# 5            Liberation Tigers of Tamil Eelam (LTTE)   10831    10919
# 6                                         Al-Shabaab    9282     7620
# 7                    Tehrik-i-Taliban Pakistan (TTP)    6030     9528
# 8                                   Al-Qaida in Iraq    4342    10273
# 9                                  Shining Path (SL)   11385     3015
# ...

# %%
#3- What are the primary targets of terrorist attacks, and have they shifted over time?
TargetCount_df = gtd_df_copy.groupby(['Year','Target_type'])['Target_type'].count().unstack()
TargetCount_df = TargetCount_df.drop(columns = ['Unknown'], errors = 'ignore')
TargetCount_df = TargetCount_df.fillna(0.0)
TargetCount_df.head(10)
# Out:
# Target_type  Abortion Related  Airports & Aircraft  Business  \
# Year
# 1970                      0.0                 25.0     131.0
# 1971                      0.0                 10.0     121.0
# 1972                      0.0                 22.0      70.0
# 1973                      0.0                 20.0      83.0
# 1974                      0.0                 20.0     176.0
# 1975                      0.0                 19.0     200.0
# 1976                      0.0                 43.0     214.0
# 1977                      4.0                 30.0     366.0
# 1978                      6.0                 36.0     381.0
# 1979                      1.0                 63.0     500.0
#
# Target_type  Educational Institution  Food or Water Supply  \
# Year
# 1970                            62.0                   2.0
# 1971                            40.0                   0.0
# 1972                             6.0                   0.0
# ...

# %%
#4- Which countries have experienced the most significant increase or decrease in terrorism in recent years?

# Terrorist  Incident -> + (Increase)
# Terrorist  Incident -> - (Decrease)

# Recent Years Range
start_year_recent = 2012
end_year_recent = 2017

# Previous Years Range
start_year_previous = 2007
end_year_previous = 2012

# Filter data for recent years
recent_period_df = gtd_df_copy[(gtd_df_copy['Year'] >= start_year_recent) & (gtd_df_copy['Year'] <= end_year_recent)]
# Filter data for previous years
previous_period_df = gtd_df_copy[(gtd_df_copy['Year'] >= start_year_previous) & (gtd_df_copy['Year'] <= end_year_previous)]

#Count number of incidents by Country
incident_recent = recent_period_df.groupby('Country')['Country'].count()
incident_previous = previous_period_df.groupby('Country')['Country'].count()

#Calculte Incident Change
incident_change = incident_recent - incident_previous

#Create Dataframe from incident change
recent_change_df = pd.DataFrame({"Country": incident_change.index, "IncidentChange": incident_change.values})
recent_change_df = recent_change_df.sort_values('IncidentChange', ascending = False)
recent_change_df = recent_change_df.head(20)
# correct Index of the values
recent_change_df.reset_index(drop = True, inplace = True)
recent_change_df
# Out:
#                              Country  IncidentChange
# 0                               Iraq          8482.0
# 1                        Afghanistan          5810.0
# 2                           Pakistan          3928.0
# 3                        Philippines          2351.0
# 4                              Yemen          2281.0
# 5                            Nigeria          2250.0
# 6                              Libya          2126.0
# 7                            Somalia          2069.0
# 8                              Egypt          1849.0
# 9                              India          1740.0
# 10                             Syria          1734.0
# 11                           Ukraine          1566.0
# 12                            Turkey          1123.0
# 13                        Bangladesh           767.0
# 14                             Sudan           491.0
# 15          West Bank and Gaza Strip           484.0
# 16                              Mali           462.0
# ...

# %%
#5- What is the distribution of suicide attacks across different regions and years?
selected_regions = ['Middle East & North Africa', 'South Asia', 'Sub-Saharan Africa', 'Eastern Europe', 'Western Europe', 'Central Asia']
suicideatk_df = gtd_df_copy[(gtd_df_copy['Region'].isin(selected_regions)) & (gtd_df_copy['Year'] >= 2000)]
# suicideatk_df = gtd_df_copy[gtd_df_copy['Year']>=2000]
suicideatk_df = suicideatk_df.groupby(['Region', 'Year'])['Suicide'].sum().reset_index()
suicideatk_df = suicideatk_df.sort_values('Suicide',ascending = False)
suicideatk_df.reset_index(drop = True, inplace = True)
suicideatk_df.head(15)
# Out:
#                         Region  Year  Suicide
# 0   Middle East & North Africa  2016      687
# 1   Middle East & North Africa  2015      509
# 2   Middle East & North Africa  2017      446
# 3   Middle East & North Africa  2014      428
# 4   Middle East & North Africa  2013      353
# 5                   South Asia  2014      231
# 6   Middle East & North Africa  2007      223
# 7                   South Asia  2013      213
# 8           Sub-Saharan Africa  2017      204
# 9           Sub-Saharan Africa  2015      201
# 10                  South Asia  2012      189
# 11                  South Asia  2015      188
# 12  Middle East & North Africa  2005      180
# 13                  South Asia  2017      170
# 14                  South Asia  2016      151

# %%
#6 How have international terrorist incidents evolved over time, and which regions are most affected?
intl_incidents_df = gtd_df_copy[gtd_df_copy['Country']!= gtd_df_copy['Nationality']]
intl_incidents_df = intl_incidents_df.groupby(['Year','Region','Country'])['Country'].count().reset_index(name = 'IncidentCount')
# consider only international Incidents
intl_incidents_df = gtd_df_copy[gtd_df_copy['Country'] != gtd_df_copy['Nationality']]
# Group data by year, region, country and count the incidents
intl_incidents_df = intl_incidents_df.groupby(['Year', 'Region', 'Country'])['Country'].count().reset_index(name ='IncidentCount')
# find region with most incidents each year
# intl_incidents_df = intl_incidents_df.groupby('Year')['Region','IncidentCount'].apply(lambda x: x.loc[x['IncidentCount'].idxmax()]).reset_index(drop = True)
intl_incidents_df = intl_incidents_df.groupby('Year').apply(lambda x: x.loc[x['IncidentCount'].idxmax()]).reset_index(drop = True)
intl_incidents_df.head(10)
# Out:
#    Year          Region         Country  IncidentCount
# 0  1970   North America   United States             27
# 1  1971  Western Europe  United Kingdom             81
# 2  1972  Western Europe  United Kingdom            291
# 3  1973  Western Europe  United Kingdom            189
# 4  1974  Western Europe  United Kingdom            202
# 5  1975  Western Europe  United Kingdom            194
# 6  1976  Western Europe  United Kingdom            194
# 7  1977  Western Europe  United Kingdom            110
# 8  1978  Western Europe  United Kingdom             97
# 9  1979  Western Europe  United Kingdom            207

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# How was the frequency of terrorists attacks changed over past decade?
import matplotlib.pyplot as plt
import seaborn as sns
# Create a new column 'Decade' by dividing the 'Year' by 10 and rounding down
gtd_df_copy['Decade'] = (gtd_df_copy['Year'] // 10)*10
# Grouping the data by 'Decade' and counting the number of incidents for each decade
atkBydecade = gtd_df_copy.groupby('Decade')['Decade'].count()
# Creating a custom DataFrame
atkBydecade_df = pd.DataFrame({'Decade': atkBydecade.index, 'IncidentCount':atkBydecade.values })

# Set up Seaborn style
sns.set(style="whitegrid")
# Create a bar plot using Seaborn
plt.figure(figsize=(10, 5))
sns.lineplot(x='Decade', y='IncidentCount', data=atkBydecade_df, marker = 'o')
plt.title('Terrorist Incidents by Decade')
plt.xlabel('Decade')
plt.ylabel('Number of Incidents')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected this line chart to illustrate the progressive trend in the frequency of terrorist incidents spanning from the 1970s to 2010. Notably, the data highlights a significant surge in incidents during the 2010 decade, surpassing 80,000 occurrences.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Insight**:-
# The year 1970 marked the lowest count of terrorist incidents, while the peak occurred in 2010. This rise can be attributed to a lack of security awareness during that decade.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Lead to negative growth**:- The chart illustrates a concerning upward trend in terrorist incidents from 1970 to 2010. During this period, there was a significant rise in the frequency of these incidents, leading to substantial human casualties and security threats. The data highlights an alarming pattern of increasing violence, particularly in recent decades. This underscores the urgency of comprehending and tackling the underlying causes of these incidents to mitigate their devastating effects on societies and global security.
#
#
#
#
#
# .

# %% [markdown]
# **Positive business impact**:-
# Exploiting the rising number of terrorist incidents over the years, our arms selling company sees an opportunity to increase profits by supplying weapons to government and Indian security organizations. This approach capitalizes on the demand for enhanced security measures in the face of escalating threats.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Which terrorist groups have been responsible for the largest number of casualties?
import pandas as pd
import matplotlib.pyplot as plt

# Grouping the data by 'Group' and calculating the sum of killed and wounded for each group
group_casualties_df = gtd_df_copy.groupby('Group')['Killed', 'Wounded'].sum()

# Summing up killed and wounded to calculate total casualties for each group
group_casualties_df['TotalCasualties'] = group_casualties_df['Killed'] + group_casualties_df['Wounded']

# Sorting the DataFrame by total casualties
group_casualties_df = group_casualties_df.sort_values('TotalCasualties', ascending=False)

# Resetting the index and creating a custom DataFrame
group_casualties_df = group_casualties_df.reset_index()

# Display the custom DataFrame
group_casualties_df = group_casualties_df.head(11)
group_casualties_df.drop(0, inplace=True)
group_casualties_df

# Create a pie chart using Matplotlib
plt.figure(figsize=(10, 10))
sns.set_palette('Paired')
plt.pie(group_casualties_df['TotalCasualties'], labels=group_casualties_df['Group'], autopct='%1.1f%%', startangle=140, pctdistance=0.85, labeldistance=1.05)
plt.title('Top 10 Terrorist Groups by Total Casualties')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
# Draw a circle in the center to create a donut chart effect
centre_circle = plt.Circle((0,0),0.60,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-48-589e62be8b5c>:7: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   group_casualties_df = gtd_df_copy.groupby('Group')['Killed', 'Wounded'].sum()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart highlights the top 10 terrorist groups based on casualties. The Islamic State of Iraq and the Levant (ISIL) stands out with 24.8% of casualties, followed by the Taliban with 20.4%.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Insight**:-
# Among the top 10 terrorist groups, including FMLA, SL, Al-Qaida in Iraq, Taliban, Boko Haram, Al-Qaida, ISIL, LTTE, AL-Shabaab, and TTP, the highest casualties are attributed to ISIL and Taliban. These two groups account for approximately 45% of the total casualties

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Lead to negative growth**:- In this segment, we can identify the top 10 terrorist groups that pose a significant threat to global security. Among them, ISIL and the Taliban stand out as particularly concerning. Together, these two groups alone account for 45.2% of the total casualties caused by these organizations.

# %% [markdown]
# **Positive business impact**:-
# "In response to the increasing threat posed by terrorist groups carrying out attacks nationwide, our security IT organization proposes offering advanced security trackers and devices to government authorities. This initiative not only enhances national security but also promises substantial profit gains."

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# What are the primary targets of terrorist attcks and have they shifted over time?
import pandas as pd
import matplotlib.pyplot as plt

# Create a cross-tabulation to count occurrences of target types by year
cross_tab = pd.crosstab(gtd_df_copy['Year'], gtd_df_copy['Target_type'])

sns.set_palette('Paired')

# Create a stacked bar plot using Matplotlib
ax = cross_tab.plot(kind='area', stacked=True, figsize=(15,6))
plt.title('Primary Targets of Terrorist Attacks Over Time')
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
# plt.legend(title='Target Type')
# Move the legend outside of the chart using bbox_to_anchor
plt.legend(title='Target Type', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The area chart visually captures the predominant target types and their distribution across decades. It highlights that targets such as business, government (general), police, private citizens & property, and unknown entities have been the most frequently targeted over various decades.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Insight**:- I selected this area chart due to its depiction of various target types, including business, government, military, police, private citizens & property, and some cases where the target type is unspecified. Among these, private citizens & property appear to be the most frequently targeted category.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Lead to negative growth**:- The selected area chart clearly indicates that terrorists have primarily targeted businesses, government institutions, military installations, police forces, as well as private citizens and properties. This has resulted in significant economic and security losses for the country, particularly since 2010.

# %% [markdown]
# **Positive business impact**:-
# Maximize profits and enhance national security by strategically offering advanced, highly efficient weaponry to the Indian government in regions witnessing high casualty rates.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# Which countries have experienced the most significant increase or decrease in terrorism in recent years?
# Terrorist  Incident -> + (Increase)
# Terrorist  Incident -> - (Decrease)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Recent Years Range
start_year_recent = 2012
end_year_recent = 2017

# Previous Years Range
start_year_previous = 2007
end_year_previous = 2012

# Filter data for recent years
recent_period_df = gtd_df_copy[(gtd_df_copy['Year'] >= start_year_recent) & (gtd_df_copy['Year'] <= end_year_recent)]
# Filter data for previous years
previous_period_df = gtd_df_copy[(gtd_df_copy['Year'] >= start_year_previous) & (gtd_df_copy['Year'] <= end_year_previous)]

#Count number of incidents by Country
incident_recent = recent_period_df.groupby('Country')['Country'].count()
incident_previous = previous_period_df.groupby('Country')['Country'].count()

#Calculte Incident Change
incident_change = incident_recent - incident_previous

#Create Dataframe from incident change
recent_change_df = pd.DataFrame({"Country": incident_change.index, "IncidentChange": incident_change.values})
recent_change_df = recent_change_df.sort_values('IncidentChange', ascending = False)
recent_change_df = recent_change_df.head(20)
# correct Index of the values
recent_change_df.reset_index(drop = True, inplace = True)
recent_change_df


# Set up Seaborn style
sns.set(style="whitegrid")
# Create a bar plot using Seaborn
plt.figure(figsize=(18, 8))
sns.barplot(y='IncidentChange', x='Country', data=recent_change_df)
plt.title('Countries with the Most Significant Incident Changes')
plt.xlabel('Incident Change')
plt.ylabel('Country')
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart effectively illustrates countries with significant incident changes, highlighting Iraq as the leader with 8481 incidents changed

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Insight**:-
# The bar chart illustrates a significant number of incident changes, with Iraq leading at 8481 incidents and Afghanistan following closely with 5810 incidents. This notable shift in incidents is quite evident.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impact**:- Develop a predictive model to anticipate and mitigate the impact of global terrorism incidents, enhancing global security and minimizing potential casualties and for gaining the profits as an IT organization.

# %% [markdown]
# **Lead to negative growth**:- These incident changes in all these countries will harm the national securities of those countries. It is a very negative thing in the point of view of the countries security.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# What is the Distribution of Suicide Attacks across different Region and Years?
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

selected_regions = ['Middle East & North Africa', 'South Asia', 'Sub-Saharan Africa', 'Eastern Europe', 'Western Europe', 'Central A']
suicide_df = gtd_df_copy[(gtd_df_copy['Region'].isin(selected_regions)) & (gtd_df_copy['Year'] >= 2000)]

# Grouping the data by 'Region', 'Year', and calculating the sum of suicide attacks
suicideatk_df = suicide_df.groupby(['Region', 'Year'])['Suicide'].sum().reset_index()

# Sort the DataFrame by the sum of suicide attacks
suicideatk_df = suicideatk_df.sort_values('Suicide', ascending=False)

# Resetting the index
suicideatk_df.reset_index(drop=True, inplace=True)
suicideatk_df.head(15)
# Visualize the data using Seaborn
plt.figure(figsize=(16, 5))
sns.barplot(data=suicideatk_df, x='Year', y='Suicide', hue='Region')
plt.title('Distribution of Suicide Attacks Across Different Regions and Years')
plt.xlabel('Year')
plt.ylabel('Number of Suicide Attacks')
plt.xticks(rotation = 90)
plt.legend(title='Region')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chosen group bar chart effectively illustrates the distribution of suicide attacks across various regions and years. It provides a clear depiction of the number of attacks in each region for the specified years. This visually appealing chart allows for easy identification of regions with higher or lower incidences of suicide attacks over the given time frame.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Insight**:-
# The year 2000 saw the lowest number of suicide attacks across all regions. However, in 2016, the Middle East & North Africa experienced the highest with around 690 incidents. In 2014, South Asia recorded 230 suicide attacks, while Sub-Saharan Africa saw 200 each in 2015 and 2017.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impact**:- The recent years have witnessed a significant increase in suicide attacks in the Middle East & North Africa, South Asia, and Sub-Saharan Africa. This trend presents an opportunity for our organization to potentially increase weapon sales and generate higher profits within these regions.

# %% [markdown]
# **Lead to negative growth**:- The group bar chart illustrates a recent surge in suicide attacks across the Middle East & North Africa, South Asia, and Sub-Saharan Africa. This alarming trend has significantly impacted national security in these regions.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# How have international terrorist incidents evolved over time, and which regions are most affected
import matplotlib.pyplot as plt
import seaborn as sns
# consider only international Incidents
intl_incidents_df = gtd_df_copy[gtd_df_copy['Country'] != gtd_df_copy['Nationality']]
# Group data by year, region, country and count the incidents
intl_incidents_df = intl_incidents_df.groupby(['Year', 'Region', 'Country'])['Country'].count().reset_index(name ='IncidentCount')
# find region with most incidents each year
# intl_incidents_df = intl_incidents_df.groupby('Year')['Region','IncidentCount'].apply(lambda x: x.loc[x['IncidentCount'].idxmax()]).reset_index(drop = True)
intl_incidents_df1 = intl_incidents_df.groupby('Year').apply(lambda x: x.loc[x['IncidentCount'].idxmax()]).reset_index(drop = True)

plt.figure(figsize=(16, 6))
sns.lineplot(data = intl_incidents_df1, x = 'Year', y = 'IncidentCount', hue = 'Region', marker = 'o')
plt.title("Most affected Region")
plt.xlabel("Year")
plt.ylabel('Incident Count')
plt.legend(title = 'Region')
plt.xticks(rotation = 90)
plt.xticks(range(1970, 2018, 1))
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The line chart is the most fitting choice to depict the progression of the most affected regions from 1970 to 2017. It distinctly presents the impact each region experienced annually, showcasing notable trends. For instance, in 2012, South Asia exhibited the highest level of impact with over 400 recorded incidents, establishing it as the most affected region that year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Insight**:- In 2012, South Asia experienced the highest number of incidents, totaling around 430. Conversely, North America reported the lowest incidents, with approximately 20, in 1970. Notably, from 1971 to 2010, Western Europe faced a persistent series of incidents.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impact**:-
# From 1970 to 2010, Western Europe experienced a significant impact in terms of incident counts. However, in recent years, South Asia has emerged as the most affected region. As an IT organization, we can capitalize on this by offering electronic trackers designed to help these countries monitor and mitigate terrorist attacks, thereby fostering business growth.

# %% [markdown]
# **Lead to negative growth**:- The line chart indicates that between 1970 and 2010, Western Europe experienced the highest impact, while in recent years, South Asia has become the most affected region in terms of incident counts. These incidents have significantly impacted the financial growth of the regions, leading to a weakening of their overall economic strength.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Select only the numerical columns for the heatmap
numerical_columns = ['Killed', 'Wounded', 'Success', 'Multiple', 'Year', 'Day', 'Month', 'Suicide', 'Latitude', 'Longitude']

# Create a correlation matrix
correlation_matrix = gtd_df_copy[numerical_columns].corr()

plt.figure(figsize=(14,7))
sns.set(font_scale=1.2)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title("Correlation Heatmap of Numerical Columns")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The correlation heatmap presents a comprehensive visual representation, effectively elucidating relationships among variables within a dataset. By displaying correlations, it offers a clear picture of how multiple variables interrelate, aiding in data analysis and insights.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Insight**:- When I talk about this correlation heatmap chart

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
gtd_df_copy['Success'].value_counts()
# Out:
# True     153221
# False     19147
# Name: Success, dtype: int64

# %%
# Pair Plot visualization code
# Select the suitable numeric columns for the pair plot
numeric_columns = ['Killed', 'Wounded', 'Year', 'Day']

# Add the 'Success' column to the numeric columns
numeric_columns.append('Success')

# Create the pair plot
Success_colors = {False: 'orangered', True: 'cornflowerblue'}
# sns.pairplot(telecom_df[numeric_columns], hue='Success', diag_kind='kde', palette='tab10')
sns.pairplot(gtd_df[numeric_columns], hue='Success', diag_kind='kde', palette=Success_colors)

# Adjust plot layout
plt.subplots_adjust(top=0.95)  # Add space for the title
plt.suptitle('Pair Plot of Suitable Columns with Success as Hue', fontsize=16)

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected this pair plot chart with the chosen variables because they are the only ones available with continuous values in our topic. This type of chart effectively illustrates the data and has an appealing visual presentation. The blue and red color scheme enhances its aesthetics and readability.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Insights**:- The pair plot chart displays success rates using blue for true and red for false outcomes. It represents casualties as wounded and killed counts over various years and days. This visualization helps assess success rates by considering the total of wounded and killed incidents.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Certainly, here are 10 efficient points that businesses can consider for achieving their objectives amidst the challenges posed by global terrorism between 1970 and 2017:
#
# 1) Expand operations and explore markets that are less affected by regions prone to terrorism, minimizing potential disruptions to business operations.
#
# 2) Develop a robust supply chain strategy that includes multiple suppliers and distribution channels, reducing vulnerability to disruptions caused by terrorist activities.
#
# 3)  Conduct thorough risk assessments to identify potential terrorism-related threats and vulnerabilities, and implement mitigation strategies to safeguard business continuity.
#
# 4) Establish a well-defined crisis communication plan to efficiently address stakeholders, employees, and customers during and after terrorist incidents, maintaining transparency and trust.
#
# 5) Build a flexible remote work infrastructure to enable employees to continue working during times of heightened security risks, ensuring minimal disruptions to productivity.
#
# 6) Invest in stringent security measures, such as access control systems, surveillance technologies, and employee training programs to enhance physical and digital security within the workplace.
#
# 7) Foster strong partnerships with local law enforcement agencies and government bodies to receive timely updates on security threats and participate in coordinated response efforts.
#
# 8) Develop scenario-based business continuity plans that account for various levels of disruption caused by terrorism, enabling swift adaptation and recovery.
#
# 9) Prioritize the well-being of employees by offering psychological support services, counseling, and training to help them cope with the psychological impact of terrorism.
#
# 10) Embrace technological advancements such as remote collaboration tools, data encryption, and AI-driven threat detection to enhance security and operational efficiency.
#
# These points can help businesses navigate the challenges posed by global terrorism during the specified time frame, enabling them to pursue their objectives while maintaining resilience and adaptability.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
